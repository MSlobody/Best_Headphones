# %% [markdown]
# # Gathering Data:
#
# - Using the Best Buy API, a function was developed to acquire any information about a desired product category
# - There is a limit of 5 calls per second and 50,000 calls per day
# - Product information is returned as a dataframe where rows = products and columns = attributes
#
# ## Additional Information:
#
# - best buy API: https://developer.bestbuy.com/
# - instructions: https://bestbuyapis.github.io/api-documentation/?shell#getting-started

# %%
#import libraries
import urllib.request, urllib.parse, urllib.error
import json
import ssl
import pandas as pd
import numpy as np
import time

# %%
def query_bestbuy(category, api_key, active = "*", manufacturer = "*", show = "all", sort = "salePrice.dsc",
                  page_size = "100", next_page ="*", pages = 1):
    """
    query_bestbuy extracts information about a particular product category from the bestbuy website.
    
    Parameters
    ----------
    :param category: Name of a particular product category. Must be a plural noun. 
    :param api_key: Unique user api key acquired from https://developer.bestbuy.com/
    :param active: Active and/or inactive products. By default set to "*" to show all.
    :param manufacturer: Manufacturer name for a product category. By default all manufacturers are shown.
    :param show: Control which attributes are returned. By default set to "all".
    :param sort: Sort the results by one of the attributes. By default sorted by "salePrice" in descending order.
    :param page_size: Control the number of product entries per page. By default 100 entries per page are returned.
    :param next_page: A unique "CursorMark" is provided for each product page. To walk through each page, next_page
                      must be set to "*" and then it is iteratively updated to the next "CursorMark".
    :param pages: Number of pages requested. By default this is set to 1.
    
    Returns
    -------
    :return: pandas dataframe, where rows = product and columns = attributes.
    """ 
    #Ensure the input names are URL suitable (quoting special characters and appropriately encoding non-ASCII text)
    category = urllib.parse.quote(category)
    show = urllib.parse.quote(show)
    
    #Using an API key and customizable parameters, open the best buy URL and load the accompanying json data
    try:
        serviceurl = f'https://api.bestbuy.com/v1/products(categoryPath.name={category}&active={active}'\
                        f'&manufacturer={manufacturer})?format=json&show={show}&sort={sort}&pageSize={page_size}'\
                        f'&cursorMark={next_page}&apiKey={api_key}'
        uh = urllib.request.urlopen(serviceurl)
        data = uh.read().decode()
        js_pg1 = json.loads(data)
    
    #If issues arise with the api key,information is missing or an item can't be found then an error is returned
    except urllib.error.HTTPError as e:
        if e.code == 403:
            return("The API key is not valid, or the allocated call limit has been exceeded.")
        elif e.code == 400:
            return("The request is missing key information or is malformed.")
        elif e.code == 404:
            return("The requested item cannot be found.")
    
    #If a particular category doesn't have any entries then an error is thrown
    if js_pg1['totalPages'] == 0:
        raise ValueError("No information is available for this category")
        
    #If more pages are requested than there are available an error is provided. 0 pages cannot be provided either.
    elif pages > js_pg1['totalPages'] or pages == 0:
        raise ValueError('The number of pages requested must be between 1 and %d' %(js_pg1['totalPages']))
  
    #Iterate through each page and save product information in a dataframe (rows = product,columns = attributes)
    output = pd.DataFrame()
    for i in range(js_pg1['totalPages']): 
        time.sleep(0.1)
        
        #Save information from the first page into a dataframe and acquire the unique next page "CursorMark"
        if i == 0:
            next_page = js_pg1['nextCursorMark']
            next_page = urllib.parse.quote(next_page)
            for d in js_pg1['products']:
                df_dictionary = pd.DataFrame([d])
                output = pd.concat([output, df_dictionary], ignore_index=True)
                
        #For subsequent pages make a new URL request, load the data, append it to the dataframe and save 
        #the unique next page "CursorMark"
        elif i >= 1:
            serviceurl = f'https://api.bestbuy.com/v1/products(categoryPath.name={category}&active={active}'\
                            f'&manufacturer={manufacturer})?format=json&show={show}&sort={sort}&pageSize={page_size}'\
                            f'&cursorMark={next_page}&apiKey={api_key}'
            uh = urllib.request.urlopen(serviceurl)
            data = uh.read().decode()
            js_pgx = json.loads(data)
            
            next_page = js_pgx['nextCursorMark']
            next_page = urllib.parse.quote(next_page)
            for d in js_pgx['products']:
                df_dictionary = pd.DataFrame([d])
                output = pd.concat([output, df_dictionary], ignore_index=True)
        
        #For each iteration update the user on the current page, how many pages are left to query and which
        #information is being acquired about a specific manufacturer and product category. 
        if manufacturer == "*":
            manufacturer_name = "all"
        elif manufacturer != "*":
            manufacturer_name = manufacturer
        print("Obtaining information about {} {} on page {}. \nThere a total of {} pages left."
              .format(manufacturer_name,category,i+1,js_pg1['totalPages']-(i+1)))
        
        #Stop acquiring data at a user specified page number. 
        if pages == i+1:
            break
        
    return(output)

# %% [markdown]
# ### Example1: Obtaining information about the the top 50 least expensive Samsung monitors.

# %%
df_SamsungMonitors = query_bestbuy(category = "Monitors",api_key = '#############',
                                   manufacturer = "Samsung",sort ="salePrice.asc",page_size = 50)

print("\nAttributes (columns) provided by Best Buy:\n{}".format(list(df_SamsungMonitors.columns)))
# Out:
# Obtaining information about Samsung Monitors on page 1.
# There a total of 5 pages left.
#
# Attributes (columns) provided by Best Buy:
# ['sku', 'score', 'productId', 'name', 'source', 'type', 'startDate', 'new', 'active', 'lowPriceGuarantee', 'activeUpdateDate', 'regularPrice', 'salePrice', 'clearance', 'onSale', 'planPrice', 'priceWithPlan', 'contracts', 'priceRestriction', 'priceUpdateDate', 'digital', 'preowned', 'carriers', 'planFeatures', 'devices', 'carrierPlans', 'technologyCode', 'carrierModelNumber', 'earlyTerminationFees', 'monthlyRecurringCharge', 'monthlyRecurringChargeGrandTotal', 'activationCharge', 'minutePrice', 'planCategory', 'planType', 'familyIndividualCode', 'validFrom', 'validUntil', 'carrierPlan', 'outletCenter', 'secondaryMarket', 'frequentlyPurchasedWith', 'accessories', 'relatedProducts', 'requiredParts', 'techSupportPlans', 'crossSell', 'salesRankShortTerm', 'salesRankMediumTerm', 'salesRankLongTerm', 'bestSellingRank', 'url', 'spin360Url', 'mobileUrl', 'affiliateUrl', 'addToCartUrl', 'affiliateAddToCartUrl', 'linkShareAffiliateUrl', 'linkShareAffiliateAddToCartUrl', 'search', 'upc', 'productTemplate', 'categoryPath', 'alternateCategories', 'lists', 'customerReviewCount', 'customerReviewAverage', 'customerTopRated', 'format', 'freeShipping', 'freeShippingEligible', 'inStoreAvailability', 'inStoreAvailabilityText', 'inStoreAvailabilityTextHtml', 'inStoreAvailabilityUpdateDate', 'itemUpdateDate', 'onlineAvailability', 'onlineAvailabilityText', 'onlineAvailabilityTextHtml', 'onlineAvailabilityUpdateDate', 'releaseDate', 'shippingCost', 'shipping', 'shippingLevelsOfService', 'specialOrder', 'shortDescription', 'shortDescriptionHtml', 'class', 'classId', 'subclass', 'subclassId', 'department', 'departmentId', 'bestBuyItemId', 'protectionPlanTerm', 'protectionPlanType', 'protectionPlanLowPrice', 'protectionPlanHighPrice', 'buybackPlans', 'protectionPlans', 'protectionPlanDetails', 'productFamilies', 'productVariations', 'aspectRatio', 'screenFormat', 'lengthInMinutes', 'mpaaRating', 'plot', 'plotHtml', 'studio', 'theatricalReleaseDate', 'description', 'manufacturer', 'modelNumber', 'images', 'image', 'largeFrontImage', 'mediumImage', 'thumbnailImage', 'largeImage', 'alternateViewsImage', 'angleImage', 'backViewImage', 'energyGuideImage', 'leftViewImage', 'accessoriesImage', 'remoteControlImage', 'rightViewImage', 'topViewImage', 'albumTitle', 'artistName', 'artistId', 'originalReleaseDate', 'parentalAdvisory', 'mediaCount', 'monoStereo', 'studioLive', 'condition', 'inStorePickup', 'friendsAndFamilyPickup', 'homeDelivery', 'quantityLimit', 'fulfilledBy', 'members', 'bundledIn', 'albumLabel', 'genre', 'color', 'depth', 'dollarSavings', 'percentSavings', 'tradeInValue', 'height', 'orderable', 'weight', 'shippingWeight', 'width', 'warrantyLabor', 'warrantyParts', 'softwareAge', 'softwareGrade', 'platform', 'numberOfPlayers', 'softwareNumberOfPlayers', 'esrbRating', 'longDescription', 'longDescriptionHtml', 'cast', 'crew', 'details', 'includedItemList', 'features', 'offers', 'marketplace', 'listingId', 'sellerId', 'shippingRestrictions', 'discs', 'commerceSku', 'haulawayAvailable', 'proposition65WarningMessage', 'proposition65WarningType', 'brightnessCdPerSqM', 'contrastRatio', 'depthWithStandIn', 'depthWithoutStandIn', 'displayType', 'energyStarQualified', 'headphoneJacks', 'heightWithStandIn', 'heightWithoutStandIn', 'mountBracketVesaPattern', 'productAspectRatio', 'productHeightIn', 'screenSizeIn', 'screenRefreshRateHz', 'dviInputs', 'smartCapable', 'threeDReady', 'usbPort', 'collection']

# %%
df_SamsungMonitors.loc[:,["name","salePrice","customerReviewCount", "customerReviewAverage","longDescription"]]
# Out:
#                                                  name  salePrice  \
# 0   Samsung - Geek Squad Certified Refurbished 23....      71.99
# 1   Samsung - SE65 Series LS24E65KPLH/GO 23.6” LED...      79.99
# 2   Samsung - SF350 Series S19F350HNN 19" LED HD M...      89.99
# 3   Samsung - Refurbished TE310 Series T24E310ND 2...      89.99
# 4                         Samsung - 18.5" LCD Monitor      99.99
# 5   Samsung - 24" LED FHD AMD FreeSync Monitor wit...      99.99
# 6   Samsung - Geek Squad Certified Refurbished 24"...     107.99
# 7       Samsung - 21.5" LED HD Monitor - Glossy Black     109.99
# 8              Samsung - 19.5" LED HD Monitor - Black     111.99
# 9                Samsung - 21.5" LED HD Monitor - Red     118.99
# 10  Samsung - 21.5" Widescreen Flat-Panel LED HD M...     119.99
# 11  Samsung - Refurbished SD300 Series S24D300HL 2...     119.99
# 12  Samsung - SyncMaster 220 Series 18.5" LED HD M...     119.99
# 13  Samsung - Refurbished SF352 Series S24F352FHN ...     119.99
# 14  Samsung - T350 Series 24" IPS LED FHD, FreeSyn...     119.99
# 15  Samsung - Geek Squad Certified Refurbished 24"...     125.99
# 16  Samsung - Geek Squad Certified Refurbished SF3...     128.99
# 17  Samsung - 22" LED FHD Monitor - High glossy black     129.99
# 18  Samsung - Geek Squad Certified Refurbished 22"...     129.99
# 19  Samsung - 23.6" Widescreen LCD HD Monitor - Ma...     129.99
# 20  Samsung - 420 Series 18.5" Widescreen Flat-Pan...     133.99
# 21  Samsung - Refurbished SE650 Series S24E650PL 2...     135.99
# 22  Samsung - 220 Series 19" Widescreen Flat-Panel...     135.99
# 23  Samsung - SyncMaster 20" LCD Monitor - Charcoa...     139.99
# 24  Samsung - 390 Series 24" LED Curved FHD FreeSy...     139.99
# 25     Samsung - 21.5" Flat-Panel LED Monitor - Black     139.99
# 26     Samsung - 23.6" LED FHD Monitor - Glossy black     139.99
# 27  Samsung - SE348 Series S22E348A 22" LED FHD Mo...     139.99
# 28  Samsung - SF350 Series S24F350FHN 24" LED FHD ...     142.99
# 29  Samsung - Geek Squad Certified Refurbished T35...     143.99
# 30               Samsung - SyncMaster 20" LCD Monitor     149.99
# 31  Samsung - 20" Widescreen Flat-Panel LED HD Mon...     149.99
# 32  Samsung - SE370 Series S24E370DL 23.6" LED FHD...     149.99
# 33  Samsung - 21.5" LED HD Monitor - High Glossy B...     149.99
# 34                          Samsung - 20" LCD Monitor     149.99
# 35  Samsung - 20" Widescreen Flat-Panel LED HD Mon...     151.99
# 36  Samsung - Geek Squad Certified Refurbished 24"...     152.99
# 37       Samsung - 22" Widescreen LCD Monitor - Black     159.99
# 38       Samsung - SyncMaster 20" LCD Monitor - Black     159.99
# 39             Samsung - 21.5" Widescreen LED Monitor     159.99
# 40  Samsung - TE310 Series T24E310ND 23.6" LED HD ...     159.99
# 41  Samsung - CF390 Series C22F390FHN 22" LED Curv...     159.99
# 42  Samsung - T350 Series 27" IPS LED FHD, AMD Fre...     159.99
# 43  Samsung - Refurbished SD300 Series 21.5" LED F...     159.99
# 44  Samsung - 20" Widescreen Flat-Panel LCD Monito...     159.99
# 45      Samsung - 23.6" LED HD Monitor - Glossy Black     160.99
# 46  Samsung - 21.5" Widescreen Flat-Panel LED Monitor     169.99
# 47               Samsung - SyncMaster 22" LCD Monitor     169.99
# 48          Samsung - 23.6" HD Monitor - Glossy White     169.99
# 49  Samsung - Refurbished SD300 Series S22D300HY 2...     169.99
#
#    customerReviewCount customerReviewAverage  \
# 0                    1                   5.0
# 1                  108                   4.6
# 2                    2                   4.0
# 3                    1                   4.0
# 4                    1                   5.0
# 5                   13                   4.5
# 6                    2                   4.5
# 7                 1038                   4.6
# 8                   88                   4.6
# 9                  605                   4.6
# 10                  42                   4.3
# 11                   6                   4.2
# 12                None                  None
# 13                   1                   5.0
# 14                2007                   4.6
# 15                   8                   4.0
# 16                   7                   3.9
# 17                 220                   4.6
# 18                None                  None
# 19                  15                   3.5
# 20                None                  None
# 21                None                  None
# 22                None                  None
# 23                   1                   5.0
# 24                5247                   4.7
# 25                   3                   2.3
# 26                   4                   5.0
# 27                   1                   5.0
# 28                1500                   4.6
# 29                   2                   2.5
# 30                   1                   1.0
# 31                None                  None
# 32                   6                   5.0
# 33                   1                   5.0
# 34                  34                   4.1
# 35                  75                   4.6
# 36                   5                   2.4
# 37                   1                   5.0
# 38                  27                   4.6
# 39                   4                   2.3
# 40                None                  None
# 41                   3                   4.7
# 42                1098                   4.6
# 43                None                  None
# 44                  19                   4.2
# 45                 255                   4.6
# 46                   5                   4.6
# 47                   1                   4.0
# 48                   8                   4.5
# 49                None                  None
#
#                                       longDescription
# 0   Geek Squad&#174; Certified Refurbished product...
# 1   Our SE650 Series provides an environmentally f...
# 2   Display content efficiently with this 19-inch ...
# 3   Access online and broadcast entertainment with...
# 4   Perfect High Speed Performance  With a respons...
# 5   The SR35 FHD monitor has a 3-sided bezel-less ...
# 6   Geek Squad&#174; Certified Refurbished product...
# 7   Utilizing Samsung MagicAngle, MagicBright and ...
# 8   This Samsung S20D300H 19.5" LED HD monitor fea...
# 9   With 250 cd/m&#178; brightness and support for...
# 10  View Web sites, movies, games and more in stun...
# 11  View crystal-clear multimedia with this 23.6-i...
# 12  Enjoy crisp images with this 18.5" Samsung Syn...
# 13  Browse through Full HD content intuitively wit...
# 14  Seamless screen with 3-sided border-less displ...
# 15  Geek Squad&#174; Certified Refurbished product...
# 16  Geek Squad&#174; Certified Refurbished product...
# 17  View high-definition images comfortably with t...
# 18  Geek Squad&#174; Certified Refurbished product...
# 19  Enjoy brilliant, vibrant images while playing ...
# 20  Enjoy movies and games in stunning clarity wit...
# 21  Introduce this Samsung LED monitor in your off...
# 22  This 19" Samsung 220 Series S19B220NW widescre...
# 23  Presenting high performance monitors that suit...
# 24  Enjoy an immersive viewing experience with thi...
# 25  Enjoy vibrant images while playing video games...
# 26  Enhance your viewing experience with this 23.6...
# 27  Experience crisp images with this 22-inch Sams...
# 28  Set up a slim gaming desktop design with this ...
# 29  Engage in immersive gameplay with this 27-inch...
# 30  The Samsung S20A300B 20" Class Widescreen LED ...
# 31  View movies, games and more in striking clarit...
# 32  Samsung SE370DL is the monitor with an integra...
# 33  This Samsung S22C150N 21.5" LED HD monitor fea...
# 34  Imagine a sculpture that doubles as a valuable...
# 35  Watch video games, movies and graphics burst t...
# 36  Geek Squad&#174; Certified Refurbished product...
# 37  This brilliant LCD monitor features an incredi...
# 38  Samsung SyncMaster S20A350B 20-inch Widescreen...
# 39  This Samsung S22A100N 21.5" widescreen monitor...
# 40  The Samsung TE310 series LED TV monitor combo ...
# 41  Enjoy crisp, clear images with this 21.5-inch ...
# 42  Seamless screen with 3-sided border-less displ...
# 43  View images and video with exceptional picture...
# 44  Enjoy stunning visuals with this LCD monitor t...
# 45  Become immersed in games, clearly view photos ...
# 46  This LED monitor features 2 HDMI inputs for hi...
# 47  Samsung's LED monitors deliver a visually stun...
# 48  Watch movies and play games in crisp 1920 x 10...
# 49  Experience high-definition screen resolution w...

# %% [markdown]
# ### Example2: Obtaining specific information about the 5 most reviewed Sony headphones.

# %%
df_SonyHeadphones = query_bestbuy(category = "Headphones",api_key = '#############',
                                   manufacturer = "Sony",sort = "customerReviewCount.dsc",page_size = 5,
                                   show = "name,salePrice,customerReviewCount,customerReviewAverage,longDescription")

df_SonyHeadphones
# Out:
# Obtaining information about Sony Headphones on page 1.
# There a total of 84 pages left.
#                                                name  salePrice  \
# 0  Sony - ZX Series Wired On-Ear Headphones - Black      12.99
# 1  Sony - ZX Series Wired On-Ear Headphones - White      12.99
# 2    Sony - MDRXB50 Wired Earbud Headphones - Black      49.99
# 3     Sony - MDRXB50 Wired Earbud Headphones - Blue      49.99
# 4     Sony - EX14AP Wired Earbud Headphones - Black       7.49
#
#    customerReviewCount  customerReviewAverage  \
# 0                14346                    4.5
# 1                14346                    4.5
# 2                 6918                    4.5
# 3                 6918                    4.5
# 4                 6440                    4.4
#
#                                      longDescription
# 0  These Sony ZX Series MDRZX110/BLK headphones f...
# 1  These Sony ZX Series MDRZX110/WHI headphones f...
# 2  Enjoy crisp, powerful low-end audio with these...
# 3  Enjoy crisp, powerful low-end audio with these...
# 4  Enjoy music on your run with these Sony in-ear...

# %% [markdown]
# ### Example3: Obtain all information about headphones, which will be sorted by price. Lets first test how the function responds to an incorrect page number argument.

# %%
df_Headphones = query_bestbuy(category = "Headphones",api_key = '#############',
                              sort ="salePrice.dsc",pages = 0, page_size = 100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5533/2298992435.py in <module>
# ----> 1 df_Headphones = query_bestbuy(category = "Headphones",api_key = 'mdb8h4r7f8aa8eudc8t34asg',
#       2                               sort ="salePrice.dsc",pages = 0, page_size = 100)
#
# /tmp/ipykernel_5533/3515421779.py in query_bestbuy(category, api_key, active, manufacturer, show, sort, page_size, next_page, pages)
#      49     #If more pages are requested than there are available an error is provided. 0 pages cannot be provided either.
#      50     elif pages > js_pg1['totalPages'] or pages == 0:
# ---> 51         raise ValueError('The number of pages requested must be between 1 and %d' %(js_pg1['totalPages']))
#      52
#      53     #Iterate through each page and save product information in a dataframe (rows = product,columns = attributes)
#
# ValueError: The number of pages requested must be between 1 and 89

# %%
df_Headphones = query_bestbuy(category = "Headphones",api_key = '#############',
                              sort ="salePrice.dsc",pages = 89, page_size = 100)
df_Headphones
# Out:
# Obtaining information about all Headphones on page 1.
# There a total of 88 pages left.
# Obtaining information about all Headphones on page 2.
# There a total of 87 pages left.
# Obtaining information about all Headphones on page 3.
# There a total of 86 pages left.
# Obtaining information about all Headphones on page 4.
# There a total of 85 pages left.
# Obtaining information about all Headphones on page 5.
# There a total of 84 pages left.
# Obtaining information about all Headphones on page 6.
# There a total of 83 pages left.
# Obtaining information about all Headphones on page 7.
# There a total of 82 pages left.
# Obtaining information about all Headphones on page 8.
# There a total of 81 pages left.
# Obtaining information about all Headphones on page 9.
# There a total of 80 pages left.
# Obtaining information about all Headphones on page 10.
# There a total of 79 pages left.
# Obtaining information about all Headphones on page 11.
# There a total of 78 pages left.
# Obtaining information about all Headphones on page 12.
# There a total of 77 pages left.
# Obtaining information about all Headphones on page 13.
# There a total of 76 pages left.
# Obtaining information about all Headphones on page 14.
# There a total of 75 pages left.
# Obtaining information about all Headphones on page 15.
# There a total of 74 pages left.
# Obtaining information about all Headphones on page 16.
# There a total of 73 pages left.
# Obtaining information about all Headphones on page 17.
# There a total of 72 pages left.
# Obtaining information about all Headphones on page 18.
# There a total of 71 pages left.
# Obtaining information about all Headphones on page 19.
# There a total of 70 pages left.
# Obtaining information about all Headphones on page 20.
# There a total of 69 pages left.
# Obtaining information about all Headphones on page 21.
# There a total of 68 pages left.
# Obtaining information about all Headphones on page 22.
# There a total of 67 pages left.
# Obtaining information about all Headphones on page 23.
# There a total of 66 pages left.
# Obtaining information about all Headphones on page 24.
# There a total of 65 pages left.
# Obtaining information about all Headphones on page 25.
# There a total of 64 pages left.
# Obtaining information about all Headphones on page 26.
# There a total of 63 pages left.
# Obtaining information about all Headphones on page 27.
# There a total of 62 pages left.
# Obtaining information about all Headphones on page 28.
# There a total of 61 pages left.
# Obtaining information about all Headphones on page 29.
# There a total of 60 pages left.
# Obtaining information about all Headphones on page 30.
# There a total of 59 pages left.
# Obtaining information about all Headphones on page 31.
# There a total of 58 pages left.
# Obtaining information about all Headphones on page 32.
# There a total of 57 pages left.
# Obtaining information about all Headphones on page 33.
# There a total of 56 pages left.
# Obtaining information about all Headphones on page 34.
# There a total of 55 pages left.
# Obtaining information about all Headphones on page 35.
# There a total of 54 pages left.
# Obtaining information about all Headphones on page 36.
# There a total of 53 pages left.
# Obtaining information about all Headphones on page 37.
# There a total of 52 pages left.
# Obtaining information about all Headphones on page 38.
# There a total of 51 pages left.
# Obtaining information about all Headphones on page 39.
# There a total of 50 pages left.
# Obtaining information about all Headphones on page 40.
# There a total of 49 pages left.
# Obtaining information about all Headphones on page 41.
# There a total of 48 pages left.
# Obtaining information about all Headphones on page 42.
# There a total of 47 pages left.
# Obtaining information about all Headphones on page 43.
# There a total of 46 pages left.
# Obtaining information about all Headphones on page 44.
# There a total of 45 pages left.
# Obtaining information about all Headphones on page 45.
# There a total of 44 pages left.
# Obtaining information about all Headphones on page 46.
# There a total of 43 pages left.
# Obtaining information about all Headphones on page 47.
# There a total of 42 pages left.
# Obtaining information about all Headphones on page 48.
# There a total of 41 pages left.
# Obtaining information about all Headphones on page 49.
# There a total of 40 pages left.
# Obtaining information about all Headphones on page 50.
# There a total of 39 pages left.
# Obtaining information about all Headphones on page 51.
# There a total of 38 pages left.
# Obtaining information about all Headphones on page 52.
# There a total of 37 pages left.
# Obtaining information about all Headphones on page 53.
# There a total of 36 pages left.
# Obtaining information about all Headphones on page 54.
# There a total of 35 pages left.
# Obtaining information about all Headphones on page 55.
# There a total of 34 pages left.
# Obtaining information about all Headphones on page 56.
# There a total of 33 pages left.
# Obtaining information about all Headphones on page 57.
# There a total of 32 pages left.
# Obtaining information about all Headphones on page 58.
# There a total of 31 pages left.
# Obtaining information about all Headphones on page 59.
# There a total of 30 pages left.
# Obtaining information about all Headphones on page 60.
# There a total of 29 pages left.
# Obtaining information about all Headphones on page 61.
# There a total of 28 pages left.
# Obtaining information about all Headphones on page 62.
# There a total of 27 pages left.
# Obtaining information about all Headphones on page 63.
# There a total of 26 pages left.
# Obtaining information about all Headphones on page 64.
# There a total of 25 pages left.
# Obtaining information about all Headphones on page 65.
# There a total of 24 pages left.
# Obtaining information about all Headphones on page 66.
# There a total of 23 pages left.
# Obtaining information about all Headphones on page 67.
# There a total of 22 pages left.
# Obtaining information about all Headphones on page 68.
# There a total of 21 pages left.
# Obtaining information about all Headphones on page 69.
# There a total of 20 pages left.
# Obtaining information about all Headphones on page 70.
# There a total of 19 pages left.
# Obtaining information about all Headphones on page 71.
# There a total of 18 pages left.
# Obtaining information about all Headphones on page 72.
# There a total of 17 pages left.
# Obtaining information about all Headphones on page 73.
# There a total of 16 pages left.
# Obtaining information about all Headphones on page 74.
# There a total of 15 pages left.
# Obtaining information about all Headphones on page 75.
# There a total of 14 pages left.
# Obtaining information about all Headphones on page 76.
# There a total of 13 pages left.
# Obtaining information about all Headphones on page 77.
# There a total of 12 pages left.
# Obtaining information about all Headphones on page 78.
# There a total of 11 pages left.
# Obtaining information about all Headphones on page 79.
# There a total of 10 pages left.
# Obtaining information about all Headphones on page 80.
# There a total of 9 pages left.
# Obtaining information about all Headphones on page 81.
# There a total of 8 pages left.
# Obtaining information about all Headphones on page 82.
# There a total of 7 pages left.
# Obtaining information about all Headphones on page 83.
# There a total of 6 pages left.
# Obtaining information about all Headphones on page 84.
# There a total of 5 pages left.
# Obtaining information about all Headphones on page 85.
# There a total of 4 pages left.
# Obtaining information about all Headphones on page 86.
# There a total of 3 pages left.
# Obtaining information about all Headphones on page 87.
# There a total of 2 pages left.
# Obtaining information about all Headphones on page 88.
# There a total of 1 pages left.
# Obtaining information about all Headphones on page 89.
# There a total of 0 pages left.
#           sku score productId  \
# 0     6454189  None      None
# 1     6227404  None      None
# 2     6135450  None      None
# 3     8862206  None      None
# 4     6442577  None      None
# ...       ...   ...       ...
# 8881  8416169  None      None
# 8882  8416178  None      None
# 8883  8416211  None      None
# 8884  8605253  None      None
# 8885  8605459  None      None
#
#                                                    name source      type  \
# 0     Shure - KSE1500 Electrostatic Earphones System...   None  HardGood
# 1     Pioneer - SE MASTER1 Wired Over-the-Ear Headph...   None  HardGood
# 2     Sennheiser - HDV 820 Digital Headphones Amplif...   None  HardGood
# 3     Sennheiser - Digital Headphone Amplifier - Silver   None  HardGood
# 4     Sennheiser - HD 820 Over-the-Ear Audiophile He...   None  HardGood
# ...                                                 ...    ...       ...
# 8881      Rocketfish™ - Earbud Headphones - Gray, Clear   None  HardGood
# 8882            Rocketfish™ - Earbud Headphones - Black   None  HardGood
# 8883            Rocketfish™ - Earbud Headphones - White   None  HardGood
# 8884                        JVC - Gumy Earphone - White   None  HardGood
# 8885                  JVC - Gumy Earphone - Olive Black   None  HardGood
#
#        startDate    new  active  lowPriceGuarantee  ... haulawayAvailable  \
# 0     2021-03-08  False   False               True  ...              None
# 1     2018-04-11  False   False               True  ...              None
# 2     2017-11-15  False   False               True  ...              None
# 3     2013-05-21  False   False               True  ...              None
# 4     2020-12-01  False    True               True  ...              None
# ...          ...    ...     ...                ...  ...               ...
# 8881  2013-07-07  False   False              False  ...              None
# 8882  2013-07-07  False   False              False  ...              None
# 8883  2013-07-07  False   False              False  ...              None
# 8884  2008-09-14  False   False              False  ...              None
# 8885  2007-11-11  False   False              False  ...              None
#
#                             proposition65WarningMessage  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4     This product can expose you to chemicals inclu...
# ...                                                 ...
# 8881                                               None
# 8882                                               None
# 8883                                               None
# 8884                                               None
# 8885                                               None
#
#       proposition65WarningType             collection  powerSource  \
# 0                           04  Magnolia Home Theater          NaN
# 1                           01  Magnolia Home Theater          NaN
# 2                           04  Magnolia Home Theater      Plug-in
# 3                           04  Magnolia Home Theater      Plug-in
# 4                           04  Magnolia Home Theater          NaN
# ...                        ...                    ...          ...
# 8881                        05                    NaN          NaN
# 8882                        05                    NaN          NaN
# 8883                        05                    NaN          NaN
# 8884                        05                    NaN          NaN
# 8885                        05                    NaN          NaN
#
#      totalHarmonicDistortion multiroomCapability numberOfSpeakers  \
# 0                        NaN                 NaN              NaN
# 1                        NaN                 NaN              NaN
# 2                        NaN                 NaN              NaN
# 3                        NaN                 NaN              NaN
# 4                        NaN                 NaN              NaN
# ...                      ...                 ...              ...
# 8881                     NaN                 NaN              NaN
# 8882                     NaN                 NaN              NaN
# 8883                     NaN                 NaN              NaN
# 8884                     NaN                 NaN              NaN
# 8885                     NaN                 NaN              NaN
#
#      numberOfChannels headphoneJacks
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN
# ...               ...            ...
# 8881              NaN            NaN
# 8882              NaN            NaN
# 8883              NaN            NaN
# 8884              NaN            NaN
# 8885              NaN            NaN
#
# [8886 rows x 189 columns]

# %%
df_Headphones.to_csv('/home/mslobody/Desktop/Best_buy_Project/Data/Headphones.csv', sep = ',')
